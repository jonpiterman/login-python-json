# %% [markdown]
# # Project Login Python SMKN1 SBG
# Jalankan Cell 1 → Cell 2 untuk mulai. Cell 3 untuk simpan perubahan ke GitHub.

# %%
# CELL 1: SETUP - JALANKAN SEKALI SAJA
# !git clone https://github.com/jonpiterman/login-python-json.git
# %cd login-python-json
print("✅ Repo berhasil di-clone")
# !ls src

# %%
# CELL 2: JALANKAN PROGRAM LOGIN
# !python src/main.py

# %%
# CELL 3: SIMPAN PERUBAHAN KE GITHUB
# !git config --global user.email "jonpiterman11@gmail.com"
# !git config --global user.name "jonpiterman"
# !git add database/users.json
# !git commit -m "Update user dari Colab"
# !git push origin main
